# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_json('MyActivity.json',convert_dates=True)

# %%
df = pd.DataFrame(df)

# %%
df['time'] = df['time'].apply(pd.to_datetime)

# %%
df = df[df.subtitles.notna()]

# %%
def extract(x):
    return x[0]['name']

# %%
names = map(extract,df.subtitles)

# %%
df['names']=list(names)

# %%
df['month'] = df.time.dt.strftime('%B %Y')

# %%
df.names
# Out:
# 0       Sailing La Vagabonde
# 1            Vernon A. Keith
# 2                       UKTV
# 3              Electron Dust
# 4                     rlmcgr
#                 ...
# 6135                   Tobar
# 6136       TopolewskiFanClub
# 6137                bjnignog
# 6141             Jai Beniwal
# 6144            heartbraeker
# Name: names, Length: 4426, dtype: object

# %%
all_names=set(df.names)

# %%
len(all_names)
# Out:
# 1838

# %%
df=df.set_index('time')

# %%
df11 = df.groupby(pd.Grouper(freq='M'))['names'].value_counts().groupby('names').cumsum()

# %%
df11.max()
# Out:
# 225

# %%
df11_unstacked = df11.unstack(level=-1)

# %%
df11_unstacked
# Out:
# names                      .NET Interview Preparation videos  /Yuriy  \
# time
# 2011-10-31 00:00:00+00:00                                NaN     NaN
# 2011-11-30 00:00:00+00:00                                NaN     NaN
# 2012-01-31 00:00:00+00:00                                NaN     NaN
# 2012-04-30 00:00:00+00:00                                NaN     NaN
# 2012-05-31 00:00:00+00:00                                NaN     NaN
# ...                                                      ...     ...
# 2020-01-31 00:00:00+00:00                                NaN     NaN
# 2020-02-29 00:00:00+00:00                                NaN     NaN
# 2020-03-31 00:00:00+00:00                                NaN     NaN
# 2020-04-30 00:00:00+00:00                                NaN     NaN
# 2020-05-31 00:00:00+00:00                                NaN     NaN
#
# names                      0nedream0nedirection  1 NEWS  1947dave  1967sander  \
# time
# 2011-10-31 00:00:00+00:00                   NaN     NaN       NaN         NaN
# 2011-11-30 00:00:00+00:00                   NaN     NaN       NaN         NaN
# 2012-01-31 00:00:00+00:00                   NaN     NaN       NaN         NaN
# 2012-04-30 00:00:00+00:00                   NaN     NaN       NaN         NaN
# 2012-05-31 00:00:00+00:00                   NaN     NaN       NaN         NaN
# ...                                         ...     ...       ...         ...
# 2020-01-31 00:00:00+00:00                   NaN     NaN       NaN         NaN
# 2020-02-29 00:00:00+00:00                   NaN     NaN       NaN         NaN
# 2020-03-31 00:00:00+00:00                   NaN     NaN       NaN         NaN
# 2020-04-30 00:00:00+00:00                   NaN     1.0       1.0         NaN
# 2020-05-31 00:00:00+00:00                   NaN     NaN       NaN         NaN
#
# names                      1984dreaming  1w3rpass  2091082 TMK  \
# time
# 2011-10-31 00:00:00+00:00           NaN       NaN          NaN
# 2011-11-30 00:00:00+00:00           NaN       NaN          NaN
# 2012-01-31 00:00:00+00:00           NaN       NaN          NaN
# 2012-04-30 00:00:00+00:00           NaN       NaN          NaN
# 2012-05-31 00:00:00+00:00           NaN       NaN          NaN
# ...                                 ...       ...          ...
# 2020-01-31 00:00:00+00:00           NaN       NaN          NaN
# 2020-02-29 00:00:00+00:00           NaN       NaN          NaN
# 2020-03-31 00:00:00+00:00           1.0       NaN          NaN
# 2020-04-30 00:00:00+00:00           NaN       NaN          NaN
# 2020-05-31 00:00:00+00:00           NaN       NaN          NaN
#
# names                      20th Century Studios Singapore  ...  wottac  \
# time                                                       ...
# 2011-10-31 00:00:00+00:00                             NaN  ...     NaN
# 2011-11-30 00:00:00+00:00                             NaN  ...     NaN
# 2012-01-31 00:00:00+00:00                             NaN  ...     NaN
# 2012-04-30 00:00:00+00:00                             NaN  ...     NaN
# 2012-05-31 00:00:00+00:00                             NaN  ...     NaN
# ...                                                   ...  ...     ...
# 2020-01-31 00:00:00+00:00                             NaN  ...     NaN
# 2020-02-29 00:00:00+00:00                             NaN  ...     NaN
# 2020-03-31 00:00:00+00:00                             NaN  ...     NaN
# 2020-04-30 00:00:00+00:00                             NaN  ...     NaN
# 2020-05-31 00:00:00+00:00                             NaN  ...     NaN
#
# names                      xiaobai5  yachtportcartagena  yesladboyyeee  \
# time
# 2011-10-31 00:00:00+00:00       NaN                 NaN            NaN
# 2011-11-30 00:00:00+00:00       NaN                 NaN            NaN
# 2012-01-31 00:00:00+00:00       NaN                 NaN            NaN
# 2012-04-30 00:00:00+00:00       NaN                 NaN            NaN
# 2012-05-31 00:00:00+00:00       NaN                 NaN            NaN
# ...                             ...                 ...            ...
# 2020-01-31 00:00:00+00:00       NaN                 NaN            NaN
# 2020-02-29 00:00:00+00:00       NaN                 NaN            NaN
# 2020-03-31 00:00:00+00:00       NaN                 NaN            NaN
# 2020-04-30 00:00:00+00:00       NaN                 NaN            NaN
# 2020-05-31 00:00:00+00:00       NaN                 NaN            NaN
#
# names                      yrag1958  yronen1  zipcar  zzzng  Άρωμα Λευκάδας  \
# time
# 2011-10-31 00:00:00+00:00       NaN      NaN     NaN    NaN             NaN
# 2011-11-30 00:00:00+00:00       NaN      NaN     NaN    NaN             NaN
# 2012-01-31 00:00:00+00:00       NaN      NaN     NaN    NaN             NaN
# 2012-04-30 00:00:00+00:00       NaN      NaN     NaN    NaN             NaN
# 2012-05-31 00:00:00+00:00       NaN      NaN     NaN    NaN             NaN
# ...                             ...      ...     ...    ...             ...
# 2020-01-31 00:00:00+00:00       NaN      NaN     NaN    NaN             NaN
# 2020-02-29 00:00:00+00:00       NaN      NaN     NaN    NaN             NaN
# 2020-03-31 00:00:00+00:00       NaN      1.0     NaN    NaN             NaN
# 2020-04-30 00:00:00+00:00       NaN      NaN     NaN    1.0             NaN
# 2020-05-31 00:00:00+00:00       NaN      NaN     NaN    NaN             NaN
#
# names                      Евгений Храмов
# time
# 2011-10-31 00:00:00+00:00             NaN
# 2011-11-30 00:00:00+00:00             NaN
# 2012-01-31 00:00:00+00:00             NaN
# 2012-04-30 00:00:00+00:00             NaN
# 2012-05-31 00:00:00+00:00             NaN
# ...                                   ...
# 2020-01-31 00:00:00+00:00             NaN
# 2020-02-29 00:00:00+00:00             NaN
# 2020-03-31 00:00:00+00:00             NaN
# 2020-04-30 00:00:00+00:00             1.0
# 2020-05-31 00:00:00+00:00             NaN
#
# [96 rows x 1838 columns]

# %%
df11_unstacked = df11_unstacked.ffill()

# %%
df11_unstacked.index.name = 'date'

# %%
df12_unstacked = df11_unstacked.rank(axis=1,method='first',ascending=False)

# %%
df11_unstacked.reset_index(inplace=True)

# %%
df12_unstacked.reset_index(inplace=True)

# %%
df12_long = pd.melt(df12_unstacked,id_vars=['date'])

# %%
df12_long = df12_long.sort_values('date')

# %%
df12_long
# Out:
#                             date                              names   value
# 0      2011-10-31 00:00:00+00:00  .NET Interview Preparation videos     NaN
# 96768  2011-10-31 00:00:00+00:00                          PewDiePie     NaN
# 96672  2011-10-31 00:00:00+00:00                     Peter Woodcock     NaN
# 96576  2011-10-31 00:00:00+00:00                      Peter Sheeler     NaN
# 96480  2011-10-31 00:00:00+00:00                          Peter Kay     NaN
# ...                          ...                                ...     ...
# 116927 2020-05-31 00:00:00+00:00                         SigalaVEVO  1353.0
# 117023 2020-05-31 00:00:00+00:00                   Silicon Republic  1354.0
# 117119 2020-05-31 00:00:00+00:00                       SimpliFlying  1355.0
# 114623 2020-05-31 00:00:00+00:00                         Sea Change  1332.0
# 176447 2020-05-31 00:00:00+00:00                     Евгений Храмов  1838.0
#
# [176448 rows x 3 columns]
